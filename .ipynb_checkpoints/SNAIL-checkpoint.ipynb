# %%
from anti_qsweepy.drivers import *
from anti_qsweepy.routines import jpa_tuning
from matplotlib.pyplot import *
from numpy import *
from matplotlib import interactive
import time
import pickle
import datetime
interactive(True)
import scipy.optimize as so
import imp

# %%
imp.reload(jpa_tuning)
# Out:
# <module 'anti_qsweepy.routines.jpa_tuning' from 'C:\\simple_lab_scripts\\anti_qsweepy\\routines\\jpa_tuning.py'>

# %%
timestamp = lambda:datetime.datetime.fromtimestamp(time.time()).strftime('%d-%m_%H_%M_%S')

# %%
savepath = "E:\\data\\Abramov"

# %%
db = database.MyDatabase()
sweeper = sweep_extras.Sweeper(db, sample_name="SNAIL")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in wrap_dbapi_exceptions(func, provider, *args, **kwargs)
#      49         if provider.dialect != 'SQLite':
# ---> 50             return func(provider, *args, **kwargs)
#      51         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in connect(provider)
#     220     def connect(provider):
# --> 221         return provider.pool.connect()
#     222
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in connect(pool)
#     341             is_new_connection = True
# --> 342             pool._connect()
#     343             pool.pid = pid
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbproviders\postgres.py in _connect(pool)
#     183     def _connect(pool):
# --> 184         pool.con = pool.dbapi_module.connect(*pool.args, **pool.kwargs)
#     185         if 'client_encoding' not in pool.kwargs:
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-420a0ad2c123> in <module>
# ----> 1 db = database.MyDatabase()
#       2 sweeper = sweep_extras.Sweeper(db, sample_name="SNAIL")
#
# C:\qtlab_replacement\qsweepy\ponyfiles\database.py in __init__(self, provider, user, password, host, database, port)
#      66         self.Invalidations = Invalidations
#      67
# ---> 68         db.bind(provider, user=user, password=password, host=host, database=database, port=port)
#      69         db.generate_mapping(create_tables=True)
#      70         self.db = db
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\core.py in bind(self, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\utils\utils.py in cut_traceback(func, *args, **kwargs)
#      76             if module_name.startswith('pony.utils') and tb.tb_frame.f_code.co_name == 'throw':
#      77                 reraise(exc_type, exc, last_pony_tb)
# ---> 78             reraise(exc_type, exc, full_tb)
#      79         finally:
#      80             del exc, full_tb, tb, last_pony_tb
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\utils\utils.py in reraise(***failed resolving arguments***)
#      93 else:
#      94     def reraise(exc_type, exc, tb):
# ---> 95         try: raise exc.with_traceback(tb)
#      96         finally: del exc, tb
#      97
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\utils\utils.py in cut_traceback(func, *args, **kwargs)
#      59         return func(*args, **kwargs)
#      60
# ---> 61     try: return func(*args, **kwargs)
#      62     except AssertionError: raise
#      63     except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\core.py in bind(self, *args, **kwargs)
#     763     @cut_traceback
#     764     def bind(self, *args, **kwargs):
# --> 765         self._bind(*args, **kwargs)
#     766     def _bind(self, *args, **kwargs):
#     767         # argument 'self' cannot be named 'database', because 'database' can be in kwargs
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\core.py in _bind(self, *args, **kwargs)
#     785             provider_cls = provider_module.provider_cls
#     786         kwargs['pony_call_on_connect'] = self.call_on_connect
# --> 787         self.provider = provider_cls(*args, **kwargs)
#     788     @property
#     789     def last_sql(database):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in __init__(provider, *args, **kwargs)
#     119         if pool_mockup: provider.pool = pool_mockup
#     120         else: provider.pool = provider.get_pool(*args, **kwargs)
# --> 121         connection, is_new_connection = provider.connect()
#     122         if call_on_connect:
#     123             call_on_connect(connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in connect(provider)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pony\orm\dbapiprovider.py in wrap_dbapi_exceptions(func, provider, *args, **kwargs)
#      65     except dbapi_module.OperationalError as e:
#      66         if provider.dialect == 'SQLite': provider.restore_exception()
# ---> 67         raise OperationalError(e)
#      68     except dbapi_module.DataError as e: raise DataError(e)
#      69     except dbapi_module.DatabaseError as e: raise DatabaseError(e)
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?

# %%
from qsweepy.instruments import Agilent_E8257D as rf_generator
from qsweepy.instruments import Yokogawa_GS210 as current_source
from qsweepy.instruments import RS_ZVB20 as network_analyser
pna = network_analyser('pna', address = 'ZVB20')
pump = rf_generator('pump', address = 'Generator_E8257D')
bias = current_source(address = 'GS200')
# Out:
# Failed loading module HDAWG_1808_new:  No module named 'zhinst'
# Failed loading module Keysight_M3102A:  No module named 'keysightSD1'
# Failed loading module Keysight_M3202A:  No module named 'keysightSD1'
# C:\ProgramData\Anaconda3\lib\site-packages\pyvisa\resources\messagebased.py:617: FutureWarning:
#
# ask is deprecated and will be removed in 1.10, use query instead.

# %% [markdown]
# # Manual

# %%
pna.get_all()
# Out:
# {'nop': 500,
#  'power': 10.0,
#  'start freq': 10000000.0,
#  'stop freq': 20000000000.0,
#  'span': 19990000000.0,
#  'bw': 1000.0,
#  'sweep mode': 'LIN\n'}

# %%
pna.set_xlim(7e9, 8.5e9)

# %%
pna.set_centerfreq(13.6e9/2)

# %%
pna.set_frequency(7.75e9+1e6)
# Out:
# True

# %%
pna.set_sweep_mode('lin')
# Out:
# True

# %%
pna.set_nop(20000)
# Out:
# True

# %%
pna.set_bandwidth(100)
# Out:
# True

# %%
pna.set_power(5)
# Out:
# True

# %%
pump.get_all()
# Out:
# {'status': True, 'freq': 14370000000.0, 'power': 1.1}

# %%
pump.set_status(1)
# Out:
# True

# %%
pump.set_frequency(7.625e9*2)

# %%
pump.set_power(7.15)
# Out:
# True

# %%
pump.set_phase(-1.5)
# Out:
# True

# %%
print("Output:",bias.get_status())
print("Current:",bias.get_current())
print("Range:",bias.get_range())
# Out:
# Output: 1
# Current: 0.001731
# Range: 0.01

# %%
bias.set_range(100e-3)
# Out:
# True

# %%
bias.set_status(0)
# Out:
# True

# %%
bias.set_current(-0.7e-3 )
# Out:
# True

# %%
op = tt.ind(12)
tuner.set_op(op)

# %%
pna.post_sweep()

# %%
op.Fp
# Out:
# 14800000000.0

# %% [markdown]
# # Network analyzer snapshot

# %%
save_data = False
pna.set_sweep_mode('lin')
F = pna.get_freqpoints()
pna.pre_sweep()
data = pna.get_tracedata(format = 'REALIMAG')
S21 = data[0]+1.j*data[1]
figure("mag")
plot(F, 20*log10(abs(S21)))
figure("delay")
plot(F[1:], diff( unwrap(angle(S21)) ) )
if save_data:
    filename = "S21vsF"
    ts = timestamp()
    full_path = savepath+"\\"+ts+"_"+filename
    savefig(full_path+".png", dpi = 300)
    f = open(full_path+".pkl", 'wb')
    pickle.dump({'S21':S21, 'F':F, "Power":pna.get_power(), "Bandwidth":pna.get_bandwidth()} , f)
    f.close()
#xlim((6.95e9,7.05e9))

# %%
S21_ref = S21

# %% [markdown]
# # Network analyzer CW snapshot

# %%
f_cw = 7.25e9-2e6
filename = 'snr'

# %%
pump.set_status(1)
pna.set_sweep_mode('cw')
pna.set_frequency(f_cw)
pna.set_nop(1000)
pna.set_bandwidth(100e3)
pna.pre_sweep()
data = pna.get_tracedata(format = 'REALIMAG')
swe_time = pna.get_sweep_time()
S21_on = data[0]+1.j*data[1]
plot(S21_on.real, S21_on.imag)
pump.set_status(0)
time.sleep(0.1)
data = pna.get_tracedata(format = 'REALIMAG')
pna.post_sweep()
S21_off = data[0]+1.j*data[1]
plot(S21_off.real, S21_off.imag)
grid()
gca().set_aspect('equal')
pump.set_status(1)
xlabel("Re(S21)")
ylabel("Im(S21)")
tight_layout()
ts = timestamp()
full_path = savepath+"\\"+ts+"_"+filename
savefig(full_path+".png", dpi = 300)
f = open(full_path+".pkl", 'wb')
pickle.dump({'S21_on':S21_on, 'S21_on':S21_off, "time": swe_time, "Power":pna.get_power(), "Bandwidth":pna.get_bandwidth()} , f)
f.close()

# %%
snr_off= abs(mean(S21_off))/std(S21_off) 
snr_on = abs(mean(S21_on))/std(S21_on) 
snr_on/snr_off
# Out:
# 1.1954629344624295

# %%
f = open(savepath+'\\7GHz_S21.pkl', 'wb')
pickle.dump({'S21_on':S21_on, 'S21_on':S21_off, "time": swe_time, "Power":pna.get_power(), "Bandwidth":pna.get_bandwidth()} , f)
f.close()

# %%
mean(20*log10(abs(S21_on)))

# %% [markdown]
# # S21 pump phase dependavce

# %%
save_data =False
phases = linspace(-pi,pi,200)
pna.set_sweep_mode('cw')
pna.set_frequency(f_cw)
pna.set_nop(1)
pna.set_bandwidth(100)

S21 = array([],dtype = complex)
for ph in phases:
    pump.set_phase(ph)
    data = pna.get_tracedata(format = 'REALIMAG')
    S21 = hstack([S21,data[0]+1.j*data[1]])
plot(phases, 20*log10(abs(S21)))
if save_data:
    filename = "S21vsPhase"
    ts = timestamp()
    full_path = savepath+"\\"+ts+"_"+filename
    savefig(full_path+".png", dpi = 300)
    f = open(full_path+".pkl", 'wb')
    pickle.dump({'S21':S21, "Phase":phases ,'F':f_cw, "Power":pna.get_power(), "Bandwidth":pna.get_bandwidth()} , f)
    f.close()

# %% [markdown]
# # Gain compression

# %%
detuning = 1e6
pna.set_sweep_mode('cw')
pna.set_frequency(f_cw+detuning )
pna.set_nop(1)
pna.set_bandwidth(100)

powers = arange(-70,-5,1)
ref_p = -50
ref_bw = 100
min_bw= 1

def set_power(p):
    pna.set_power(p)
    bw = 10**((p - ref_p)/10)*ref_bw 
    if bw<min_bw:
        bw = min_bw
    pna.set_bandwidth( bw ) 
    time.sleep(0.1)
result = sweeper.sweep(pna, (powers, set_power, 'Power'), measurement_type = "gain_compression")

# %%
plot(result.datasets['S-parameter'].parameters[0].values, 20*log10(abs(result.datasets['S-parameter'].data)))

# %% [markdown]
# ## Gain compression with tuning table

# %%
tt = jpa_tuning.TuningTable()
tt.load(savepath+"\\TuningTables\\20db.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4bd17c827fe0> in <module>
# ----> 1 tt = jpa_tuning.TuningTable()
#       2 tt.load(savepath+"\\TuningTables\\20db.txt")
#
# NameError: name 'jpa_tuning' is not defined

# %%
detuning = 1e6
pna.set_sweep_mode('cw')
pna.set_nop(1)
pna.set_bandwidth(100)

pump.set_status(1)
bias.set_status(1)

powers = arange(-70,1,1)
point_ind = range(len(tt.I))
ref_p = -50
ref_bw = 100
min_bw= 1

def set_power(p):
    if p == powers[-1]:
        pna.set_power(-30)
        pna.set_bandwidth( 100 )
        pump.set_status(0)
        time.sleep(0.05)
    else:    
        pna.set_power(p)
        bw = 10**((p - ref_p)/10)*ref_bw 
        if bw<min_bw:
            bw = min_bw
        pna.set_bandwidth( bw ) 
        time.sleep(0.1)

def set_op(i):
    op = tt.ind(i)
    bias.set_current(op.I)
    pna.set_frequency(op.Fp/2.+detuning)
    pump.set_frequency(op.Fp)
    pump.set_power(op.Pp)
    pump.set_status(1)
    time.sleep(0.05)
    
result = sweeper.sweep(pna, (point_ind, set_op, 'Operating point'), (powers, set_power, 'Power'), 
                       measurement_type = "gain_compression",
                      metadata = tt.to_dict() )
# Out:
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# load time:  0.05096912384033203
# pre_trace_time:  0.0019979476928710938
# trace 0 time:  0.030980348587036133
# trace 1 time:  0.06396055221557617
# trace 2 time:  0.09494209289550781
# trace 3 time:  0.12992072105407715

# %%
op = tt.ind(4)
tuner.set_op(op)

pna.set_sweep_mode('lin')
pna.set_centerfreq( op.Fp/2 )
pna.set_nop(600)
pna.set_bandwidth(1000)

pump.set_status(1)
powers = arange(-70,-5,1)
ref_p = -50
ref_bw = 1000
min_bw= 1

def set_power(p):
    pna.set_power(p)
    bw = 10**((p - ref_p)/10)*ref_bw 
    if bw<min_bw:
        bw = min_bw
    pna.set_bandwidth( bw ) 
    time.sleep(0.1)
result = sweeper.sweep(pna, (powers, set_power, 'Power'), measurement_type = "gain_compression",
                      metadata = {'G':op.G,'Fp':op.Fp, 'Pp':op.Pp,'I':op.I} )

# %% [markdown]
# # Resonator mapping

# %%
currents = arange(-7,7.05,0.05)*1e-3
result = sweeper.sweep(pna, (currents, bias.set_current, 'Current'), measurement_type = "resonator_mapping")
# Out:
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# S-parameter
# load time:  0.03997492790222168
# pre_trace_time:  0.0009996891021728516
# trace 0 time:  0.024982929229736328
# trace 1 time:  0.04896974563598633
# trace 2 time:  0.07795143127441406
# trace 3 time:  0.1089322566986084

# %% [markdown]
# # Tuning

# %%
imp.reload(jpa_tuning)
# Out:
# <module 'jpa_tuning' from 'C:\\qtlab_replacement\\qsweepy-notebooks\\Abramov\\jpa_tuning.py'>

# %%
tuner = jpa_tuning.JpaTuner(vna = pna, pump = pump, bias = bias)

# %%
tuner.I0 = 0e-3
tuner.I05 = 3.5e-3
tuner.Pp_init = -5.
tuner.dPp_raw = 1
tuner.Ps = -40.
tuner.Pp_max = 17.
tuner.Gthr = 5.
tuner.df = 2e6

# %%
op, status = tuner.find_gain_sm(20, 7.5e9)
# Out:
# Refrence measurement...
# S21_ref = -47.13 dB
# Raw search...
# Raw search: P = -3.00 dBm I= 1.9400e-03A G = 5.08 dBB
# Noise measurement...
# G = 1.72 Sigma= 6.562864e-02
# Max search: I= 2.2140e-03A G = 3.95 dB Gmax = 5.35 dB
# Power optimization:P = 1.43 dBm G = 6.96 Gmax = 9.143
# Itune I = 2.1100e-03A P = 0.74dBm G = 6.92dB
# Itune I = 1.6160e-03A P = 0.74dBm G = 8.40dBB
# Power optimization:P = 2.07 dBm G = 12.78 Gmax = 13.84
# Itune I = 1.7800e-03A P = 1.93dBm G = 13.56dB
# Itune I = 1.6650e-03A P = 1.93dBm G = 13.73dB
# Power optimization:P = 2.05 dBm G = 13.73 Gmax = 14.64
# Itune I = 1.7800e-03A P = 1.93dBm G = 13.54dB
# Itune I = 1.6600e-03A P = 1.93dBm G = 13.48dB
# Power optimization:P = 2.09 dBm G = 13.56 Gmax = 14.53

# %%
tt.add_point(op)

# %%
tt.dump(savepath+"\\20db.txt")

# %%
target_gains = [20,]
for target_gain in target_gains:
    tt = jpa_tuning.TuningTable()
    for Fs in  arange(6.8e9, 8e9, 0.05e9) :
        print(Fs*1e-9)
        op,status = tuner.find_gain_sm(target_gain , Fs)
        #if status:
        tt.add_point(op)
        tt.dump(savepath+"\\{:.0f}db.txt".format(target_gain))
# Out:
# 6.800000000000001
# Refrence measurement...
# S21_ref = -46.45 dB
# Raw search...
# Raw search: P = -5.00 dBm I= 1.9400e-03A G = 5.31 dBB
# Noise measurement...
# G = 1.75 Sigma= 6.550605e-02
# Max search: I= 2.4880e-03A G = 20.07 dB Gmax = 20.30 dB
# Power optimization:P = -4.99 dBm G = 20.34 Gmax = 20.34
# Itune I = 2.5070e-03A P = -5.01dBm G = 19.74dB
# Itune I = 2.4150e-03A P = -5.02dBm G = 19.60dB
# 6.8500000000000005
# Refrence measurement...
# S21_ref = -46.37 dB
# Raw search...
# Raw search: P = -5.00 dBm I= 1.7200e-03A G = 5.11 dBB
# Noise measurement...
# G = 1.75 Sigma= 6.314941e-02
# Max search: I= 2.2300e-03A G = 38.90 dB Gmax = 38.96 dB
# Power optimization:P = -4.99 dBm G = 38.84 Gmax = 38.96
# 6.9
# Refrence measurement...
# S21_ref = -46.34 dB
# Raw search...
# Raw search: P = 2.00 dBm I= 2.4400e-03A G = 5.01 dBBB
# Noise measurement...
# G = 1.72 Sigma= 6.483652e-02
# Max search: I= 2.5390e-03A G = 3.73 dB Gmax = 5.11 dB
# Power optimization:P = 7.62 dBm G = 19.82 Gmax = 19.82
# Itune I = 2.4600e-03A P = 7.62dBm G = 19.23dB
# Itune I = 2.2770e-03A P = 7.27dBm G = 19.75dB
# 6.95
# Refrence measurement...
# S21_ref = -46.68 dB
# Raw search...
# Raw search: P = 15.00 dBm I= 2.1800e-03A G = 5.01 dBB
# Noise measurement...
# G = 1.79 Sigma= 6.762416e-02
# Max search: I= 2.4130e-03A G = 4.33 dB Gmax = 5.95 dB
# 7.0er optimization:P = 16.99 dBm G = 8.17 Gmax = 8.49
# Refrence measurement...
# S21_ref = -46.92 dB
# Raw search...
# Raw search: P = 11.00 dBm I= 2.2400e-03A G = 5.07 dBB
# Noise measurement...
# G = 1.78 Sigma= 7.171821e-02
# Max search: I= 2.3250e-03A G = 4.36 dB Gmax = 5.86 dB
# 7.050000000000001n:P = 16.99 dBm G = 13.74 Gmax = 14.07
# Refrence measurement...
# S21_ref = -46.90 dB
# Raw search...
# Raw search: P = 13.00 dBm I= 2.1000e-03A G = 5.29 dBB
# Noise measurement...
# G = 1.77 Sigma= 6.783593e-02
# Max search: I= 2.2800e-03A G = 4.63 dB Gmax = 6.00 dB
# 7.1000000000000005:P = 16.99 dBm G = 8.43 Gmax = 9.13
# Refrence measurement...
# S21_ref = -46.95 dB
# Raw search...
# Raw search: P = 10.00 dBm I= 2.2000e-03A G = 5.31 dBB
# Noise measurement...
# G = 1.73 Sigma= 7.260484e-02
# Max search: I= 2.3210e-03A G = 3.71 dB Gmax = 5.27 dB
# Power optimization:P = 16.87 dBm G = 11.45 Gmax = 12.75
# Itune I = 2.2870e-03A P = 16.35dBm G = 11.17dB
# Itune I = 1.9160e-03A P = 15.48dBm G = 19.68dB
# 7.15
# Refrence measurement...
# S21_ref = -46.96 dB
# Raw search...
# Raw search: P = -5.00 dBm I= 2.1000e-03A G = 5.03 dBB
# Noise measurement...
# G = 1.76 Sigma= 6.996769e-02
# Max search: I= 2.3350e-03A G = 4.10 dB Gmax = 5.63 dB
# Power optimization:P = 1.70 dBm G = 19.84 Gmax = 19.841
# Itune I = 2.2480e-03A P = 1.70dBm G = 19.22dB
# Itune I = 2.0770e-03A P = 1.04dBm G = 19.71dB
# 7.2
# Refrence measurement...
# S21_ref = -47.17 dB
# Raw search...
# Raw search: P = -1.00 dBm I= 2.0000e-03A G = 5.17 dBB
# Noise measurement...
# G = 1.79 Sigma= 6.881318e-02
# Max search: I= 2.1850e-03A G = 4.76 dB Gmax = 6.06 dB
# Power optimization:P = 7.16 dBm G = 15.13 Gmax = 15.98
# Itune I = 2.1650e-03A P = 6.00dBm G = 15.03dB
# Itune I = 1.5930e-03A P = 5.65dBm G = 19.72dB
# 7.250000000000001
# Refrence measurement...
# S21_ref = -47.07 dB
# Raw search...
# Raw search: P = 6.00 dBm I= 1.9000e-03A G = 5.28 dBBB
# Noise measurement...
# G = 1.75 Sigma= 7.016085e-02
# Max search: I= 2.2390e-03A G = 4.72 dB Gmax = 6.16 dB
# Power optimization:P = 12.38 dBm G = -7.91 Gmax = 12.65
# Itune I = 2.1770e-03A P = 12.13dBm G = 11.19dB
# Itune I = 1.7730e-03A P = 12.13dBm G = 13.16dB
# Power optimization:P = 12.29 dBm G = -0.50 Gmax = 14.19
# Itune I = 2.0000e-03A P = 12.13dBm G = 13.06dB
# Itune I = 1.7900e-03A P = 12.13dBm G = 13.22dB
# Power optimization:P = 12.31 dBm G = -1.60 Gmax = 14.23
# 7.300000000000001
# Refrence measurement...
# S21_ref = -47.07 dB
# Raw search...
# Raw search: P = 3.00 dBm I= 1.9200e-03A G = 5.14 dBBB
# Noise measurement...
# G = 1.76 Sigma= 6.735890e-02
# Max search: I= 2.1770e-03A G = 4.65 dB Gmax = 5.93 dB
# Power optimization:P = 10.05 dBm G = 11.12 Gmax = 12.35
# Itune I = 2.1340e-03A P = 8.73dBm G = 10.92dB
# Itune I = 1.6870e-03A P = 8.73dBm G = 12.25dB
# Power optimization:P = 9.38 dBm G = 12.97 Gmax = 14.01
# Itune I = 1.8920e-03A P = 9.19dBm G = 13.08dB
# Itune I = 1.6320e-03A P = 9.19dBm G = 13.95dB
# Power optimization:P = 9.53 dBm G = 14.66 Gmax = 15.54
# Itune I = 1.6960e-03A P = 9.38dBm G = 14.50dB
# Itune I = 1.6190e-03A P = 9.38dBm G = 15.57dB
# Power optimization:P = 9.64 dBm G = 16.02 Gmax = 16.77
# Itune I = 1.6670e-03A P = 9.52dBm G = 16.14dB
# Itune I = 1.6090e-03A P = 9.52dBm G = 16.75dB
# Power optimization:P = 9.74 dBm G = 17.11 Gmax = 18.03
# Itune I = 1.6430e-03A P = 9.63dBm G = 17.34dB
# Itune I = 1.5960e-03A P = 9.63dBm G = 17.37dB
# Power optimization:P = 9.73 dBm G = 17.42 Gmax = 18.14
# 7.3500000000000005
# Refrence measurement...
# S21_ref = -47.25 dB
# Raw search...
# Raw search: P = 6.00 dBm I= 2.0200e-03A G = 5.07 dBBB
# Noise measurement...
# G = 1.76 Sigma= 7.265374e-02
# Max search: I= 2.2170e-03A G = 4.13 dB Gmax = 5.57 dB
# Power optimization:P = 11.87 dBm G = 8.12 Gmax = 9.96
# Itune I = 2.1840e-03A P = 11.52dBm G = 7.84dB
# Itune I = 1.8220e-03A P = 11.52dBm G = 9.38dBB
# Power optimization:P = 12.33 dBm G = 9.43 Gmax = 11.099
# Itune I = 2.1230e-03A P = 11.75dBm G = 9.43dBB
# Itune I = 1.8500e-03A P = 11.75dBm G = 9.54dBB
# Power optimization:P = 12.28 dBm G = 9.33 Gmax = 11.099
# 7.4
# Refrence measurement...
# S21_ref = -47.42 dB
# Raw search...
# Raw search: P = 6.00 dBm I= 2.0200e-03A G = 5.32 dBBB
# Noise measurement...
# G = 1.73 Sigma= 7.405234e-02
# Max search: I= 2.1000e-03A G = 3.77 dB Gmax = 5.32 dB
# Power optimization:P = 11.99 dBm G = 8.03 Gmax = 10.044
# Itune I = 2.1210e-03A P = 11.12dBm G = 7.96dB
# Itune I = 1.8020e-03A P = 11.12dBm G = 8.68dBB
# Power optimization:P = 11.50 dBm G = 8.97 Gmax = 10.666
# 7.45
# Refrence measurement...
# S21_ref = -47.33 dB
# Raw search...
# Raw search: P = 10.00 dBm I= 1.8600e-03A G = 5.02 dBB
# Noise measurement...
# G = 1.69 Sigma= 7.002541e-02
# Max search: I= 2.0340e-03A G = 3.91 dB Gmax = 5.53 dB
# Power optimization:P = 12.05 dBm G = 2.84 Gmax = 5.96
# Itune I = 2.1600e-03A P = 10.89dBm G = 2.59dB
# Itune I = 1.6180e-03A P = 10.89dBm G = 3.11dB
# Power optimization:P = 12.34 dBm G = 3.54 Gmax = 6.33
# 7.500000000000001
# Refrence measurement...
# S21_ref = -47.29 dB
# Raw search...
# Raw search: P = -3.00 dBm I= 2.0200e-03A G = 5.21 dBB
# Noise measurement...
# G = 1.77 Sigma= 6.886371e-02
# Max search: I= 2.2150e-03A G = 3.89 dB Gmax = 5.47 dB
# Power optimization:P = 1.25 dBm G = 6.11 Gmax = 8.781
# Itune I = 2.1230e-03A P = 0.55dBm G = 6.54dB
# Itune I = 1.6200e-03A P = 0.55dBm G = 8.17dB
# Power optimization:P = 1.96 dBm G = 12.97 Gmax = 14.17
# Itune I = 1.7840e-03A P = 1.85dBm G = 13.76dB
# Itune I = 1.6660e-03A P = 1.85dBm G = 13.77dB
# Power optimization:P = 2.00 dBm G = 13.57 Gmax = 14.74
# Itune I = 1.7890e-03A P = 1.85dBm G = 13.65dB
# Itune I = 1.6610e-03A P = 1.85dBm G = 13.66dB
# Power optimization:P = 2.02 dBm G = 13.69 Gmax = 14.66
# 7.550000000000001
# Refrence measurement...
# S21_ref = -47.47 dB
# Raw search...
# Raw search: P = 0.00 dBm I= 1.9600e-03A G = 5.50 dBBB
# Noise measurement...
# G = 1.76 Sigma= 6.971415e-02
# Max search: I= 2.0910e-03A G = 4.28 dB Gmax = 5.67 dB
# Power optimization:P = 4.32 dBm G = 6.92 Gmax = 8.92
# Itune I = 2.1370e-03A P = 3.74dBm G = 6.77dB
# Itune I = 1.7660e-03A P = 3.74dBm G = 7.97dB
# Power optimization:P = 4.75 dBm G = 9.80 Gmax = 11.355
# Itune I = 1.9630e-03A P = 4.66dBm G = 9.63dBB
# Itune I = 1.8440e-03A P = 4.66dBm G = 10.35dB
# Power optimization:P = 4.78 dBm G = 10.15 Gmax = 11.75
# 7.6000000000000005
# Refrence measurement...
# S21_ref = -47.54 dB
# Raw search...
# Raw search: P = 4.00 dBm I= 2.0200e-03A G = 5.13 dBBB
# Noise measurement...
# G = 1.75 Sigma= 7.282516e-02
# Max search: I= 2.1530e-03A G = 4.00 dB Gmax = 5.50 dB
# Power optimization:P = 7.50 dBm G = 2.59 Gmax = 7.88
# Itune I = 2.0860e-03A P = 7.06dBm G = 5.26dB
# Itune I = 1.7960e-03A P = 7.06dBm G = 6.70dB
# Power optimization:P = 8.05 dBm G = 7.30 Gmax = 9.42
# Itune I = 2.0100e-03A P = 7.80dBm G = 7.17dB
# Itune I = 1.8630e-03A P = 7.80dBm G = 7.34dB
# Power optimization:P = 8.06 dBm G = 7.44 Gmax = 9.39
# 7.65
# Refrence measurement...
# S21_ref = -47.73 dB
# Raw search...
# Raw search: P = 4.00 dBm I= 1.9800e-03A G = 5.24 dBBB
# Noise measurement...
# G = 1.69 Sigma= 6.887130e-02
# Max search: I= 2.1290e-03A G = 3.72 dB Gmax = 5.25 dB
# Power optimization:P = 7.32 dBm G = 4.90 Gmax = 7.32
# Itune I = 2.0500e-03A P = 6.96dBm G = 3.29dB
# Itune I = 1.7980e-03A P = 6.96dBm G = 5.90dB
# Power optimization:P = 7.91 dBm G = 6.06 Gmax = 8.58
# 7.7
# Refrence measurement...
# S21_ref = -47.50 dB
# Raw search...
# Raw search: P = 1.00 dBm I= 1.8400e-03A G = 5.02 dBBB
# Noise measurement...
# G = 1.80 Sigma= 7.010465e-02
# Max search: I= 2.0440e-03A G = 4.82 dB Gmax = 6.34 dB
# Power optimization:P = 3.28 dBm G = 5.15 Gmax = 7.75
# Itune I = 2.0070e-03A P = 2.67dBm G = 3.58dB
# Itune I = 1.8360e-03A P = 2.67dBm G = 5.24dB
# Power optimization:P = 3.50 dBm G = 5.58 Gmax = 8.00
# 7.750000000000001
# Refrence measurement...
# S21_ref = -47.75 dB
# Raw search...
# Raw search: P = 5.00 dBm I= 1.9200e-03A G = 5.42 dBBB
# Noise measurement...
# G = 1.82 Sigma= 7.579932e-02
# Max search: I= 1.9930e-03A G = 4.36 dB Gmax = 5.89 dB
# Power optimization:P = 7.20 dBm G = 4.65 Gmax = 7.43
# Itune I = 2.3460e-03A P = 6.62dBm G = 4.67dB
# Itune I = 2.0170e-03A P = 6.62dBm G = 4.17dB
# Power optimization:P = 8.20 dBm G = 5.28 Gmax = 7.92
# Itune I = 2.3070e-03A P = 7.57dBm G = 6.20dB
# Itune I = 2.0330e-03A P = 7.57dBm G = 6.36dB
# Power optimization:P = 8.51 dBm G = 6.95 Gmax = 9.28
# Itune I = 2.2640e-03A P = 7.84dBm G = 6.94dB
# Itune I = 2.0410e-03A P = 7.84dBm G = 7.11dB
# Power optimization:P = 8.97 dBm G = 7.87 Gmax = 9.78
# 7.800000000000001
# Refrence measurement...
# S21_ref = -47.75 dB
# Raw search...
# Raw search: P = 3.00 dBm I= 1.8800e-03A G = 5.25 dBBB
# Noise measurement...
# G = 1.78 Sigma= 7.124667e-02
# Max search: I= 1.9320e-03A G = 1.25 dB Gmax = 5.69 dB
# Power optimization:P = 3.01 dBm G = 1.77 Gmax = 5.69
# 7.8500000000000005
# Refrence measurement...
# S21_ref = -47.93 dB
# Raw search...
# Raw search: P = 5.00 dBm I= 1.7800e-03A G = 5.00 dBBB
# Noise measurement...
# G = 1.76 Sigma= 7.509406e-02
# Max search: I= 1.8850e-03A G = 3.49 dB Gmax = 6.02 dB
# Power optimization:P = 11.25 dBm G = 14.82 Gmax = 15.74
# Itune I = 1.9600e-03A P = 10.90dBm G = 15.02dB
# Itune I = 1.8300e-03A P = 10.90dBm G = 15.13dB
# Power optimization:P = 11.53 dBm G = 15.11 Gmax = 16.06
# 7.9
# Refrence measurement...
# S21_ref = -47.90 dB
# Raw search...
# Raw search: P = 5.00 dBm I= 2.0800e-03A G = 5.01 dBBB
# Noise measurement...
# G = 1.74 Sigma= 7.621122e-02
# Max search: I= 2.2020e-03A G = 3.49 dB Gmax = 5.18 dB
# Power optimization:P = 12.26 dBm G = 12.98 Gmax = 14.10
# Itune I = 2.1600e-03A P = 11.46dBm G = 12.71dB
# Itune I = 1.7750e-03A P = 11.46dBm G = 18.38dB
# Power optimization:P = 11.69 dBm G = 19.75 Gmax = 19.75
# Itune I = 1.8560e-03A P = 11.69dBm G = 19.42dB
# Itune I = 1.7630e-03A P = 11.69dBm G = 19.32dB
# 7.95
# Refrence measurement...
# S21_ref = -47.92 dB
# Raw search...
# Raw search: P = 0.00 dBm I= 1.9800e-03A G = 5.39 dBBB
# Noise measurement...
# G = 1.77 Sigma= 7.530568e-02
# Max search: I= 2.1150e-03A G = 3.78 dB Gmax = 5.45 dB
# Power optimization:P = 7.07 dBm G = 15.67 Gmax = 16.56
# Itune I = 2.0890e-03A P = 6.57dBm G = 15.59dB
# Itune I = 1.7310e-03A P = 6.08dBm G = 19.67dB

# %%
status
# Out:
# True

# %%
op,status = tuner.find_gain(20. , 6.9e9)
# Out:
# Refrence measurement...
# S21_ref = 1.39 dB
# Raw search...
# I= -1.4300e-03A G = 20.45 dB
# Noise measurement...
# G = 10.64 Sigma= 1.380806e-01
# Fine search...
# I = -2.0370e-03A P = 13.34dBm G = 19.46dB

# %%
S21on, S21off, F  = tuner.vna_snapshot( op, 2e9, bw = 100,Ps = -40)
plot(F, 20*log10(abs(S21on)))
plot(F, 20*log10(abs(S21off)))

# %%
op.Pp = 13

# %% [markdown]
# ## Save em all

# %%
tt = jpa_tuning.TuningTable()
tt.load(savepath+"\\20db.txt")

# %%
for i,op in enumerate(tt):
    S21on, S21off, F  = tuner.vna_snapshot( op, 2e9, bw = 50, Ps = -45)
    clf()
    plot(F, 20*log10(abs(S21on)))
    plot(F, 20*log10(abs(S21off)))
    
    filename = "{:d}".format(i)
    full_path = savepath+"\\20db\\"+filename
    
    savefig(full_path+".png", dpi = 300)
    
    f = open(full_path+".pkl", 'wb')
    pickle.dump({'S21on':S21on,'S21off':S21off,  'F':F, } , f)
    f.close()

# %%
tt.dump(savepath+"\\table.txt")

# %%
tt.load(savepath+"\\table.txt")

# %%
tt.I

# %%
figure('test')
Plist = arange(12,13,1)
Ilist = arange(0.,-4.5e-3, -0.02e-3)
gain = zeros( [len(Plist), len(Ilist)] )
for i, P in enumerate(Plist):
    #pump.set_power(P)
    for j,I in enumerate(Ilist):
        bias.set_current(I)
        time.sleep(0.05)
        print('{:.2f} {:e}'.format(P,I), end = '\r')
        gain[i][j] = abs(tuner.meas_S21()[0])
# Out:
# 12.00 -4.480000e-03

# %%
pcolormesh( sqrt((gain-20)**2) )
colorbar()
clim([0,100])

# %%
for g in gain:
    plot(Ilist,log10(g)*20)
    plot(op.I, 20,'o')

# %%
op.I
# Out:
# -0.002632000000000007

# %%
tt[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6e91a60038f2> in <module>
# ----> 1 tt[1]
#
# TypeError: 'TuningTable' object is not subscriptable
